# %% [markdown]
# # Problem 1.3 Probability foundations
#
# (a) In class, we derived the closed form solution for µ, the mean of the multivariate
# Gaussian (Eq. 1). Do the same for Σ, after making the assumption that it is diagonal.
#
# Answer:
#
# ![p1.3a](./cs5788%20hw1%20p1.3a.excalidraw.png)

# %% [markdown]
# (b) Derive the mean of a single-variable Gaussian mixture model (Eq. 4).
#
# ![](cs5788%20hw1%20p1.3b.excalidraw.png)

# %% [markdown]
# (c) Suppose $X \sim \mathcal{N}(\mu, \Sigma)$. Use the change of variables to show that the whitened variable $Z=\Sigma^{-\frac{1}{2}}(X-\mu)$
# is distributed as $Z \sim \mathcal{N}(0, I)
# $
#
# ![](./cs5788%20hw1%20p1.3c.excalidraw.png)

# %% [markdown]
# (d) Show that:
# $$
# D_{\mathrm{KL}}\!\left(\mathcal{N}(0,1)\,\|\,\mathcal{N}(\mu,\sigma)\right)
# = \log(\sigma) + \frac{1+\mu^2}{2\sigma^2} - \frac{1}{2}
# $$

# %% [markdown]
# ![](./cs5788%20hw1%20p1.3d.excalidraw.png)
